# %%
  from internetarchive import get_item

# %%
import pandas as pd

# %%
ia_ids=[]

# %%
with open('ids.txt', 'r') as file:
    
    for line in file:
        ia_ids.append(line.strip("\n"))

# %%
ia_ids=ia_ids[300000+430300+971779+1112900:]

# %%
count=0
with open('metadata7.csv', 'a', encoding="utf-8") as write_file:
    print("id,title,author,camera,contributor,publish_date,language,operator,ppi,repub_state,scanner,scanningcenter,sponsor,scandate,imagecount,republisher_operator,republisher_date,republisher_time,scanfee,sponsordate,ocr_converted,page_number_confidence,search_date", file=write_file)
    for i in ia_ids:   
        try:
            item = get_item(i)
            meta=item.item_metadata["metadata"]
        except:
            print(count)
            continue
            
        out=""
        out+=i+","
        try:
            out+=meta["title"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["creator"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["camera"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["contributor"].replace(",","").replace("\n","")+","
            
        except:
            out+=","        
        try:
            out+=meta["date"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["language"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["operator"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["ppi"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["repub_state"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["scanner"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["scanningcenter"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["sponsor"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["scandate"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["imagecount"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["republisher_operator"].replace(",","").replace("\n","")+","
        except:
            out+=","
            
        try:
            out+=meta["republisher_date"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["republisher_time"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["scanfee"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["sponsordate"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["ocr_converted"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["page_number_confidence"].replace(",","").replace("\n","")+","
        except:
            out+=","
        try:
            out+=meta["publicdate"].replace(",","").replace("\n","")+","
        except:
            out+=","
        print(out, file=write_file)
        count+=1
# Out:
# 320
# 493
# 838
# 988
# 1084
# 1481
# 1547
# 1555
# 1558
# 2360
# 2464
# 2497
# 2501
# 2508
# 2517
# 2529
# 2531
# 2564
# 3661
# 3884
# 3966
# 4075
# 4075
# 4077
# 4078
# 4078
# 4368
# 4513
# 4589
# 4594
# 4594
# 4594
# 4599
# 4615
# 4780
# 4792
# 5230
# 5504
# 5542
# 7148
# 7227
# 7252
# 7834
# 8263
# 8682
# 8926
# 9242
# 9268
# 9309
# 9394
# 9406
# 9420
# 9494
# 9496
# 9515
# 9517
# 9593
# 9610
# 9682
# 9700
# 9714
# 9718
# 9720
# 9725
# 9740
# 9812
# 9838
# 9856
# 9876
# 9879
# 9885
# 10238
# 10253
# 11214
# 11421
# 11974
# 12145
# 12380
# 12576
# 13391
# 13754
# 14053
# 14288
# 14648
# 15290
# 15292
# 15316
# 15332
# 15551
# 15627
# 15659
# 15683
# 15765
# 16373
# 17322
# 17570
# 17668
# 17808
# 18048
# 18127
# 19781
# 19957
# 20207
# 20447
# 20696
# 20753
# 20901
# 21171
# 21362
# 21436
# 21458
# 21691
# 21937
# 22046
# 22310
# 22571
# 22571
# 22575
# 22575
# 22607
# 22608
# 22608
# 22725
# 22869
# 22874
# 22901
# 23639
# 24238
# 24238
# 24238
# 24238
# 24241
# 24241
# 24241
# ...

# %%
df_firstn = pd.read_csv("ol_dump_editions_2022-08-31.txt", nrows=100)

# %%
with open('ids.txt', 'a') as write_file:
    with open("ol_dump_editions_2022-08-31.txt") as myfile:
        for line in myfile:
            try:
                temp=line.split('"ocaid": "')[1]
                print(temp.split('"')[0], file=write_file)
            except:
                continue
